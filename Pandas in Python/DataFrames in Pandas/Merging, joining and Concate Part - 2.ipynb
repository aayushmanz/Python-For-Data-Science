# %%
import pandas as pd
import numpy as np

courses =pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/datasets /courses.csv')
delivery = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/datasets /deliveries.csv')
matches = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/datasets /matches.csv')
nov = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/datasets /reg-month1.csv')
dec = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/datasets /reg-month2.csv')
std = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/datasets /students.csv')
