# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/workspaces/Python-For-Data-Science/Database from Kaggle/Messy_Employee_dataset.csv')

df.sample(20)
# Out:
#     Employee_ID First_Name Last_Name   Age      Department_Region    Status  \
# 181     EMP1181      Heidi     Davis   NaN      DevOps-California    Active
# 419     EMP1419      Frank    Miller  30.0               HR-Texas   Pending
# 468     EMP1468    Charlie     Jones   NaN       Finance-New York    Active
# 250     EMP1250      Alice    Miller  25.0       Cloud Tech-Texas   Pending
# 546     EMP1546      Alice     Jones  25.0        Finance-Florida    Active
# 844     EMP1844        Eva     Jones  30.0          Sales-Florida    Active
# 657     EMP1657    Charlie  Williams  30.0          Finance-Texas    Active
# 599     EMP1599      Alice    Miller   NaN            HR-Illinois   Pending
# 628     EMP1628      Frank     Davis  40.0        DevOps-New York   Pending
# 451     EMP1451      Frank    Miller   NaN         Sales-New York   Pending
# 678     EMP1678      Frank   Johnson  30.0       Finance-Illinois  Inactive
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        1020 non-null   str
#  1   First_Name         1020 non-null   str
#  2   Last_Name          1020 non-null   str
#  3   Age                809 non-null    float64
#  4   Department_Region  1020 non-null   str
#  5   Status             1020 non-null   str
#  6   Join_Date          1020 non-null   str
#  7   Salary             996 non-null    float64
#  8   Email              1020 non-null   str
#  9   Phone              1020 non-null   int64
#  10  Performance_Score  1020 non-null   str
#  11  Remote_Work        1020 non-null   bool
# dtypes: bool(1), float64(2), int64(1), str(8)
# memory usage: 88.8 KB
