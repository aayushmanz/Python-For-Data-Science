# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/workspaces/Python-For-Data-Science/Database from Kaggle/Messy_Employee_dataset.csv')

df.sample(20)
# Out:
#     Employee_ID First_Name Last_Name   Age      Department_Region    Status  \
# 352     EMP1352      Frank     Smith  40.0             HR-Florida   Pending
# 764     EMP1764    Charlie     Jones  40.0     Finance-California  Inactive
# 913     EMP1913    Charlie   Johnson  40.0             HR-Florida  Inactive
# 540     EMP1540      David     Davis  35.0         Sales-Illinois   Pending
# 299     EMP1299      Alice    Garcia   NaN         Finance-Nevada  Inactive
# 743     EMP1743        Eva     Jones  30.0       Sales-California    Active
# 772     EMP1772      Heidi     Smith  40.0        Finance-Florida    Active
# 42      EMP1042      Alice   Johnson   NaN              HR-Nevada    Active
# 242     EMP1242      David     Brown  40.0  Cloud Tech-California   Pending
# 697     EMP1697      Heidi   Johnson  40.0       Sales-California   Pending
# 649     EMP1649      Frank     Jones  40.0       Sales-California  Inactive
# 334     EMP1334      Grace    Miller  40.0       Finance-Illinois  Inactive
# 962     EMP1962      Heidi    Miller   NaN      DevOps-California   Pending
# 491     EMP1491      Frank     Jones  25.0         Sales-New York    Active
# 275     EMP1275        Eva     Brown  35.0        DevOps-New York   Pending
# 436     EMP1436      Frank    Garcia  40.0            Sales-Texas   Pending
# 516     EMP1516      Alice    Garcia  35.0         Sales-New York    Active
# 728     EMP1728      Heidi     Jones   NaN          Admin-Florida  Inactive
# 61      EMP1061        Eva     Davis  40.0            Sales-Texas  Inactive
# 493     EMP1493      Frank    Miller  30.0          HR-California  Inactive
#
#       Join_Date     Salary                        Email       Phone  \
# 352    5/2/2023   59528.71      frank.smith@example.com -3378613714
# 764   2/21/2020   62521.50    charlie.jones@example.com -7767555627
# 913   2/19/2024   95127.91  charlie.johnson@example.com -5947372131
# 540   12/5/2023   93276.73      david.davis@example.com -6488319212
# 299   1/21/2024   51523.93     alice.garcia@example.com   -18418619
# 743    7/5/2023   68037.56        eva.jones@example.com -7235137398
# 772   5/16/2023   92007.15      heidi.smith@example.com -4159597751
# 42    12/3/2024   59400.38    alice.johnson@example.com -4918017225
# 242   3/18/2023   75823.78      david.brown@example.com -8446267145
# 697  11/28/2023   84306.44    heidi.johnson@example.com -4381199536
# 649    1/9/2021  118907.63      frank.jones@example.com -4938173597
# 334   4/24/2020   94572.37     grace.miller@example.com -2146296135
# 962   9/18/2024   81076.91     heidi.miller@example.com -8490793883
# 491   9/29/2021   99669.86      frank.jones@example.com -6652683414
# 275  12/14/2023   84230.22        eva.brown@example.com  -200053473
# 436    9/4/2021   68211.68     frank.garcia@example.com -7244617678
# 516  10/17/2023   50288.67     alice.garcia@example.com   -61558107
# 728   8/28/2023   89993.15      heidi.jones@example.com -1571840907
# 61    8/10/2021   64712.79        eva.davis@example.com -7711991807
# 493  10/31/2022   77785.96     frank.miller@example.com -7647229811
#
#     Performance_Score  Remote_Work
# 352              Poor        False
# 764           Average         True
# 913           Average        False
# 540           Average        False
# 299           Average         True
# 743           Average        False
# 772           Average         True
# 42            Average         True
# 242           Average        False
# 697           Average        False
# 649              Poor        False
# 334              Good        False
# 962              Poor        False
# 491           Average        False
# 275              Good         True
# 436              Good        False
# 516         Excellent        False
# 728           Average         True
# 61          Excellent         True
# 493         Excellent        False

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        1020 non-null   str
#  1   First_Name         1020 non-null   str
#  2   Last_Name          1020 non-null   str
#  3   Age                809 non-null    float64
#  4   Department_Region  1020 non-null   str
#  5   Status             1020 non-null   str
#  6   Join_Date          1020 non-null   str
#  7   Salary             996 non-null    float64
#  8   Email              1020 non-null   str
#  9   Phone              1020 non-null   int64
#  10  Performance_Score  1020 non-null   str
#  11  Remote_Work        1020 non-null   bool
# dtypes: bool(1), float64(2), int64(1), str(8)
# memory usage: 88.8 KB

# %%
df.head()
# Out:
#   Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0     EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1     EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2     EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3     EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4     EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
#
#     Join_Date     Salary                       Email       Phone  \
# 0    4/2/2021   59767.65       bob.davis@example.com -1651623197
# 1   7/10/2020   65304.66       bob.brown@example.com -1898471390
# 2   12/7/2023   88145.90     alice.jones@example.com -5596363211
# 3  11/27/2021   69450.99       eva.davis@example.com -3476490784
# 4    1/5/2022  109324.61  frank.williams@example.com -1586734256
#
#   Performance_Score  Remote_Work
# 0           Average         True
# 1         Excellent         True
# 2              Good         True
# 3              Good         True
# 4              Poor        False

# %%
# insert two columns and dropped the older one.

df.insert(1, 'Name', df['First_Name'] + ' ' + df['Last_Name'])
df.drop(columns=['First_Name', 'Last_Name'], inplace=True)
df
# Out:
#      Employee_ID              Name   Age   Department_Region    Status  \
# 0        EMP1000         Bob Davis  25.0   DevOps-California    Active
# 1        EMP1001         Bob Brown   NaN       Finance-Texas    Active
# 2        EMP1002       Alice Jones   NaN        Admin-Nevada   Pending
# 3        EMP1003         Eva Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004    Frank Williams  25.0  Cloud Tech-Florida    Active
# ...          ...               ...   ...                 ...       ...
# 1015     EMP2015      David Miller  30.0       HR-California    Active
# 1016     EMP2016     David Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017  Charlie Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019       Heidi Jones  30.0     DevOps-Illinois   Pending
#
#        Join_Date     Salary                         Email       Phone  \
# 0       4/2/2021   59767.65         bob.davis@example.com -1651623197
# 1      7/10/2020   65304.66         bob.brown@example.com -1898471390
# 2      12/7/2023   88145.90       alice.jones@example.com -5596363211
# 3     11/27/2021   69450.99         eva.davis@example.com -3476490784
# 4       1/5/2022  109324.61    frank.williams@example.com -1586734256
# ...          ...        ...                           ...         ...
# 1015   8/19/2023        NaN      david.miller@example.com -3546212759
# 1016   11/7/2021  100215.06     david.johnson@example.com -2508261122
# 1017   10/4/2023  114587.11  charlie.williams@example.com -1261632487
# 1018  12/16/2024   71318.79      alice.garcia@example.com -8995729892
# 1019   2/22/2021   77764.24       heidi.jones@example.com -7629745492
#
#      Performance_Score  Remote_Work
# 0              Average         True
# 1            Excellent         True
# 2                 Good         True
# 3                 Good         True
# 4                 Poor        False
# ...                ...          ...
# 1015              Good         True
# 1016              Good         True
# 1017           Average        False
# 1018              Good         True
# 1019           Average        False
#
# [1020 rows x 11 columns]

# %%
df['Age'].isnull().value_counts()  # wow 200+ values are null.
# Out:
# Age
# False    809
# True     211
# Name: count, dtype: int64

# %%
# Age :

count_age = df['Age'].value_counts()
plt.pie(count_age, labels=count_age.index, autopct="%1.1f%%")
plt.show()

# %%
Age_num = np.random.choice([30.0, 35.0, 25.5, 40.0])
df.replace(np.nan , Age_num, inplace=True)

df.sample(10)
# Out:
#     Employee_ID             Name   Age   Department_Region    Status  \
# 77      EMP1077      Grace Brown  30.0    Finance-New York   Pending
# 27      EMP1027    Heidi Johnson  30.0     Finance-Florida    Active
# 194     EMP1194      Alice Davis  35.0            HR-Texas   Pending
# 938     EMP1938     Grace Miller  30.0      Finance-Nevada   Pending
# 125     EMP1125       Bob Garcia  35.0  Finance-California   Pending
# 871     EMP1871     Alice Garcia  35.0  Cloud Tech-Florida   Pending
# 913     EMP1913  Charlie Johnson  40.0          HR-Florida  Inactive
# 670     EMP1670      Grace Smith  35.0      Admin-New York   Pending
# 875     EMP1875   Grace Williams  30.0   DevOps-California   Pending
# 639     EMP1639       Eva Garcia  30.0    Finance-Illinois    Active
#
#       Join_Date     Salary                        Email       Phone  \
# 77   12/29/2022   51887.65      grace.brown@example.com -6110627370
# 27    7/12/2020   56785.16    heidi.johnson@example.com -2761707586
# 194   11/4/2024  118415.80      alice.davis@example.com -6656749159
# 938   5/16/2021   51990.98     grace.miller@example.com -5143776935
# 125    7/1/2021  107438.46       bob.garcia@example.com  -249685497
# 871  12/15/2020  108474.65     alice.garcia@example.com  -184980424
# 913   2/19/2024   95127.91  charlie.johnson@example.com -5947372131
# 670    8/4/2021   81021.23      grace.smith@example.com -5962622821
# 875   12/3/2020   80706.28   grace.williams@example.com  -605603566
# 639   2/18/2023   55067.02       eva.garcia@example.com -5871493924
#
#     Performance_Score  Remote_Work
# 77               Good        False
# 27          Excellent         True
# 194              Good         True
# 938         Excellent         True
# 125              Good         True
# 871              Good         True
# 913           Average        False
# 670              Good        False
# 875           Average         True
# 639              Poor         True

# %%
age_count = df['Age'].value_counts()

plt.pie(age_count, labels=age_count.index, autopct="%1.1f%%")
plt.show()

# %%
df.sample(30)
# Out:
#     Employee_ID             Name   Age   Department_Region    Status  \
# 314     EMP1314   David Williams  35.0     DevOps-New York  Inactive
# 799     EMP1799     Eva Williams  30.0         HR-New York    Active
# 875     EMP1875   Grace Williams  30.0   DevOps-California   Pending
# 595     EMP1595      Frank Brown  30.0       DevOps-Nevada  Inactive
# 676     EMP1676    Charlie Brown  35.0          HR-Florida   Pending
# 954     EMP1954     Bob Williams  25.0      Sales-New York   Pending
# 837     EMP1837        Eva Jones  35.0      Admin-Illinois  Inactive
# 878     EMP1878        Eva Jones  40.0      DevOps-Florida   Pending
# 226     EMP1226      Grace Jones  30.0  Finance-California    Active
# 577     EMP1577     Frank Miller  30.0    Cloud Tech-Texas    Active
# 484     EMP1484        Bob Jones  25.0         Sales-Texas  Inactive
# 202     EMP1202      Grace Davis  30.0        Sales-Nevada    Active
# 651     EMP1651     Alice Garcia  30.0          HR-Florida   Pending
# 719     EMP1719      David Brown  30.0       HR-California    Active
# 405     EMP1405        Eva Brown  25.0   DevOps-California    Active
# 987     EMP1987        Eva Brown  25.0         HR-Illinois  Inactive
# 932     EMP1932      Grace Smith  30.0      Sales-Illinois    Active
# 279     EMP1279  Charlie Johnson  25.0        Sales-Nevada   Pending
# 664     EMP1664      Frank Smith  40.0     DevOps-Illinois   Pending
# 897     EMP1897      Alice Brown  40.0       Sales-Florida  Inactive
# 547     EMP1547        Eva Brown  30.0      Sales-New York   Pending
# 49      EMP1049     Grace Miller  30.0     DevOps-New York    Active
# 129     EMP1129      Grace Brown  40.0       DevOps-Nevada    Active
# 22      EMP1022  Charlie Johnson  35.0      Sales-Illinois  Inactive
# 892     EMP1892      Heidi Smith  40.0    Admin-California    Active
# 614     EMP1614       Eva Miller  25.0       Admin-Florida   Pending
# 14      EMP1014     Alice Garcia  25.0        Admin-Nevada    Active
# 469     EMP1469      Grace Brown  30.0       DevOps-Nevada   Pending
# 615     EMP1615   Grace Williams  30.0      Admin-Illinois    Active
# 685     EMP1685     Frank Miller  40.0        DevOps-Texas  Inactive
#
#       Join_Date     Salary                        Email       Phone  \
# 314   4/28/2020   89367.02   david.williams@example.com -2728476569
# 799    8/9/2021   69365.47     eva.williams@example.com -2650622922
# 875   12/3/2020   80706.28   grace.williams@example.com  -605603566
# 595   12/2/2024   83596.78      frank.brown@example.com -9624406305
# 676   1/18/2020   98143.90    charlie.brown@example.com -5917793237
# 954   2/13/2021   62934.73     bob.williams@example.com -9743260054
# 837   7/17/2021      30.00        eva.jones@example.com -4247310719
# 878   9/16/2020   64431.22        eva.jones@example.com -1205464753
# 226   3/22/2024   95283.03      grace.jones@example.com -8612590471
# 577    5/2/2024      30.00     frank.miller@example.com -1579039234
# 484  11/11/2024   87494.34        bob.jones@example.com -7543943534
# 202   9/26/2021   89124.54      grace.davis@example.com -2252237280
# 651    5/8/2024   62236.03     alice.garcia@example.com -3257375533
# 719   3/14/2023   77985.88      david.brown@example.com -9079779611
# 405  11/26/2022   92484.88        eva.brown@example.com -3882211456
# 987    7/5/2024   65812.02        eva.brown@example.com -3963845268
# 932  10/21/2020   64544.87      grace.smith@example.com -9885582983
# 279    5/5/2021   66972.06  charlie.johnson@example.com -1093371188
# 664    4/8/2022  109423.05      frank.smith@example.com -1128981230
# 897   7/16/2024  105861.23      alice.brown@example.com -9967331166
# 547   10/7/2023   81934.55        eva.brown@example.com -7418652056
# 49    11/5/2024   61375.12     grace.miller@example.com -1227770792
# 129  10/11/2022  117537.71      grace.brown@example.com -9594652169
# 22     3/9/2021  115023.94  charlie.johnson@example.com -6528092427
# 892  12/20/2024   70661.31      heidi.smith@example.com -5944633398
# 614   8/23/2022  110711.17       eva.miller@example.com  -687616480
# 14    6/10/2024   97633.68     alice.garcia@example.com -1734206968
# 469   6/27/2021   96241.85      grace.brown@example.com -9842673203
# 615   6/30/2023   96175.41   grace.williams@example.com -9807704604
# 685   6/13/2020  109048.24     frank.miller@example.com -8425476817
#
#     Performance_Score  Remote_Work
# 314              Poor        False
# 799           Average         True
# 875           Average         True
# 595           Average        False
# 676         Excellent        False
# 954              Good        False
# 837         Excellent        False
# 878              Poor        False
# 226              Good        False
# 577         Excellent         True
# 484           Average         True
# 202         Excellent         True
# 651         Excellent         True
# 719           Average         True
# 405              Good         True
# 987           Average         True
# 932           Average         True
# 279              Good         True
# 664           Average        False
# 897              Good         True
# 547              Poor        False
# 49          Excellent         True
# 129         Excellent        False
# 22            Average         True
# 892              Good         True
# 614         Excellent         True
# 14          Excellent         True
# 469         Excellent        False
# 615           Average         True
# 685              Poor        False

# %%
# salary :

# in salary we can see that some people salary is only 30 dollars
# thats why i am converting them into 30000 dollars.


df['Salary']= df['Salary'].replace(30.00, 30000.00)
df
# Out:
#      Employee_ID              Name   Age   Department_Region    Status  \
# 0        EMP1000         Bob Davis  25.0   DevOps-California    Active
# 1        EMP1001         Bob Brown  30.0       Finance-Texas    Active
# 2        EMP1002       Alice Jones  30.0        Admin-Nevada   Pending
# 3        EMP1003         Eva Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004    Frank Williams  25.0  Cloud Tech-Florida    Active
# ...          ...               ...   ...                 ...       ...
# 1015     EMP2015      David Miller  30.0       HR-California    Active
# 1016     EMP2016     David Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017  Charlie Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019       Heidi Jones  30.0     DevOps-Illinois   Pending
#
#        Join_Date     Salary                         Email       Phone  \
# 0       4/2/2021   59767.65         bob.davis@example.com -1651623197
# 1      7/10/2020   65304.66         bob.brown@example.com -1898471390
# 2      12/7/2023   88145.90       alice.jones@example.com -5596363211
# 3     11/27/2021   69450.99         eva.davis@example.com -3476490784
# 4       1/5/2022  109324.61    frank.williams@example.com -1586734256
# ...          ...        ...                           ...         ...
# 1015   8/19/2023   30000.00      david.miller@example.com -3546212759
# 1016   11/7/2021  100215.06     david.johnson@example.com -2508261122
# 1017   10/4/2023  114587.11  charlie.williams@example.com -1261632487
# 1018  12/16/2024   71318.79      alice.garcia@example.com -8995729892
# 1019   2/22/2021   77764.24       heidi.jones@example.com -7629745492
#
#      Performance_Score  Remote_Work
# 0              Average         True
# 1            Excellent         True
# 2                 Good         True
# 3                 Good         True
# 4                 Poor        False
# ...                ...          ...
# 1015              Good         True
# 1016              Good         True
# 1017           Average        False
# 1018              Good         True
# 1019           Average        False
#
# [1020 rows x 11 columns]

# %%
# Email :

df['Email'] = df['Email'].str.replace('example', 'gmail')
df
# Out:
#      Employee_ID              Name   Age   Department_Region    Status  \
# 0        EMP1000         Bob Davis  25.0   DevOps-California    Active
# 1        EMP1001         Bob Brown  30.0       Finance-Texas    Active
# 2        EMP1002       Alice Jones  30.0        Admin-Nevada   Pending
# 3        EMP1003         Eva Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004    Frank Williams  25.0  Cloud Tech-Florida    Active
# ...          ...               ...   ...                 ...       ...
# 1015     EMP2015      David Miller  30.0       HR-California    Active
# 1016     EMP2016     David Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017  Charlie Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019       Heidi Jones  30.0     DevOps-Illinois   Pending
#
#        Join_Date     Salary                       Email       Phone  \
# 0       4/2/2021   59767.65         bob.davis@gmail.com -1651623197
# 1      7/10/2020   65304.66         bob.brown@gmail.com -1898471390
# 2      12/7/2023   88145.90       alice.jones@gmail.com -5596363211
# 3     11/27/2021   69450.99         eva.davis@gmail.com -3476490784
# 4       1/5/2022  109324.61    frank.williams@gmail.com -1586734256
# ...          ...        ...                         ...         ...
# 1015   8/19/2023   30000.00      david.miller@gmail.com -3546212759
# 1016   11/7/2021  100215.06     david.johnson@gmail.com -2508261122
# 1017   10/4/2023  114587.11  charlie.williams@gmail.com -1261632487
# 1018  12/16/2024   71318.79      alice.garcia@gmail.com -8995729892
# 1019   2/22/2021   77764.24       heidi.jones@gmail.com -7629745492
#
#      Performance_Score  Remote_Work
# 0              Average         True
# 1            Excellent         True
# 2                 Good         True
# 3                 Good         True
# 4                 Poor        False
# ...                ...          ...
# 1015              Good         True
# 1016              Good         True
# 1017           Average        False
# 1018              Good         True
# 1019           Average        False
#
# [1020 rows x 11 columns]
