# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Timestamp Object :
#
# * Time stamps reference particular moments in time (e.g, Oct 24th , 2026 at 6:00 pm)

# %% [markdown]
# * Creating Timestamp objects

# %%
# Creating a timestamp
pd.Timestamp("16/02/2004")
# Out:
# Timestamp('2004-02-16 00:00:00')

# %%
type(pd.Timestamp("16/02/2004"))
# Out:
# pandas.Timestamp

# %%
# variations
pd.Timestamp('2004/02/16')
pd.Timestamp('2004, 2,16')
pd.Timestamp("16-02-2004")
# Out:
# Timestamp('2004-02-16 00:00:00')

# %%
# only year
pd.Timestamp('2004')
# Out:
# Timestamp('2004-01-01 00:00:00')

# %%
# using text
pd.Timestamp('1 Oct 2026')
# Out:
# Timestamp('2026-10-01 00:00:00')

# %%
# providing time also
pd.Timestamp('5th january 2026 10:15am')
# Out:
# Timestamp('2026-01-05 10:15:00')

# %%
# using datatime.datetime object

import datetime as dt

dt.datetime(2026,2,16,21,56)
# Out:
# datetime.datetime(2026, 2, 16, 21, 56)

# %%
x = pd.Timestamp(dt.datetime(2026,2,16,21,56))
x
# Out:
# Timestamp('2026-02-16 21:56:00')

# %%
x.year
# Out:
# 2026

# %%
x.month
# Out:
# 2

# %%
x.day
# Out:
# 16

# %%
x.hour
x.min
x.second
# Out:
# 0

# %% [markdown]
# **why separate objects to handle data and time when python already has datetime functionality?**
#
# * syntax wise datetime is very convenient
# * But the performance takes a hit while working with huge data. List vs Numpy Array
# * The weakness of Python's datetime format inspired the NumPy team to add a set of native time series data type to NumPy.
# * The datetime64 dtype encodes dates as 64-bit integers, and thus allows arrays of dates to be represented very compactly.

# %%
import numpy as np
date = np.array('2004-02-16', dtype=np.datetime64)
date
# Out:
# array('2004-02-16', dtype='datetime64[D]')

# %%
date + np.arange(12)
# Out:
# array(['2004-02-16', '2004-02-17', '2004-02-18', '2004-02-19',
#        '2004-02-20', '2004-02-21', '2004-02-22', '2004-02-23',
#        '2004-02-24', '2004-02-25', '2004-02-26', '2004-02-27'],
#       dtype='datetime64[D]')

# %% [markdown]
# 1. _Because of the uniform type in NumPy datetime64 arrays, this type of operation can be accomplished much more quickly than if we were working directly with Python's datetime objects, especially as arrays get large_
#
# 2. _Pandas Timestamp object combines the ease-of-use of python datetime with the efficient storage and vectorized interface of numpy.datetime64_
#
# 3. _From a group of these Timestamp objects, Pandas can construct a DatetimeIndex that can be used to index data in a Series or DataFrame_

# %% [markdown]
# **DatetimeIndex Object**
#
# * _A collection of pandas timestamp_

# %%
# from Strings

pd.DatetimeIndex(['2004/2/16','2005/2/16','2006/2/16'])
# for storing multiple date time we use datetimeindex
# Out:
# DatetimeIndex(['2004-02-16', '2005-02-16', '2006-02-16'], dtype='datetime64[us]', freq=None)

# %%
pd.DatetimeIndex(['2004/2/16','2005/2/16','2006/2/16'])[0]
# showing or storing the one datetime obj we use timestamps
# Out:
# Timestamp('2004-02-16 00:00:00')

# %%
# using python datetime object
pd.DatetimeIndex([dt.datetime(2026, 1,1), dt.datetime(2026, 1,3),dt.datetime(2026, 1,2)])
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-03', '2026-01-02'], dtype='datetime64[us]', freq=None)

# %%
# using pd.Timestamp
dt_index = pd.DatetimeIndex([pd.Timestamp(2026, 1,1), pd.Timestamp(2026, 1,3),pd.Timestamp(2026, 1,2)])

# %%
# using datetimeindex as series index
pd.Series([1,2,3], index=dt_index)
# Out:
# 2026-01-01    1
# 2026-01-03    2
# 2026-01-02    3
# dtype: int64

# %% [markdown]
# **Date_range function**

# %%
# generate daily dates in given range.
pd.date_range(start='2026/1/1', end='2026/1/31', freq='D')
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04',
#                '2026-01-05', '2026-01-06', '2026-01-07', '2026-01-08',
#                '2026-01-09', '2026-01-10', '2026-01-11', '2026-01-12',
#                '2026-01-13', '2026-01-14', '2026-01-15', '2026-01-16',
#                '2026-01-17', '2026-01-18', '2026-01-19', '2026-01-20',
#                '2026-01-21', '2026-01-22', '2026-01-23', '2026-01-24',
#                '2026-01-25', '2026-01-26', '2026-01-27', '2026-01-28',
#                '2026-01-29', '2026-01-30', '2026-01-31'],
#               dtype='datetime64[us]', freq='D')

# %%
pd.date_range(start='2026/1/1', end='2026/1/31', freq='3D')
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-04', '2026-01-07', '2026-01-10',
#                '2026-01-13', '2026-01-16', '2026-01-19', '2026-01-22',
#                '2026-01-25', '2026-01-28', '2026-01-31'],
#               dtype='datetime64[us]', freq='3D')

# %%
# alternative days in a given range
pd.date_range(start='2026/1/1', end='2026/1/31', freq='3D')

# %%
# B -> business days
pd.date_range(start='2026/1/1', end='2026/1/31', freq='B')
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-02', '2026-01-05', '2026-01-06',
#                '2026-01-07', '2026-01-08', '2026-01-09', '2026-01-12',
#                '2026-01-13', '2026-01-14', '2026-01-15', '2026-01-16',
#                '2026-01-19', '2026-01-20', '2026-01-21', '2026-01-22',
#                '2026-01-23', '2026-01-26', '2026-01-27', '2026-01-28',
#                '2026-01-29', '2026-01-30'],
#               dtype='datetime64[us]', freq='B')

# %%
# W -> one week per day
pd.date_range(start='2026/1/1', end='2026/1/31', freq='W')
# Out:
# DatetimeIndex(['2026-01-04', '2026-01-11', '2026-01-18', '2026-01-25'], dtype='datetime64[us]', freq='W-SUN')

# %%
pd.date_range(start='2026/1/1', end='2026/1/31', freq='W-THU')
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-08', '2026-01-15', '2026-01-22',
#                '2026-01-29'],
#               dtype='datetime64[us]', freq='W-THU')

# %%
# h -> hourly data(factor)
pd.date_range(start='2026/1/1', end='2026/1/31', freq='h')
# Out:
# DatetimeIndex(['2026-01-01 00:00:00', '2026-01-01 01:00:00',
#                '2026-01-01 02:00:00', '2026-01-01 03:00:00',
#                '2026-01-01 04:00:00', '2026-01-01 05:00:00',
#                '2026-01-01 06:00:00', '2026-01-01 07:00:00',
#                '2026-01-01 08:00:00', '2026-01-01 09:00:00',
#                ...
#                '2026-01-30 15:00:00', '2026-01-30 16:00:00',
#                '2026-01-30 17:00:00', '2026-01-30 18:00:00',
#                '2026-01-30 19:00:00', '2026-01-30 20:00:00',
#                '2026-01-30 21:00:00', '2026-01-30 22:00:00',
#                '2026-01-30 23:00:00', '2026-01-31 00:00:00'],
#               dtype='datetime64[us]', length=721, freq='h')

# %%
pd.date_range(start='2026/1/1', end='2026/1/31', freq='6h')
# Out:
# DatetimeIndex(['2026-01-01 00:00:00', '2026-01-01 06:00:00',
#                '2026-01-01 12:00:00', '2026-01-01 18:00:00',
#                '2026-01-02 00:00:00', '2026-01-02 06:00:00',
#                '2026-01-02 12:00:00', '2026-01-02 18:00:00',
#                '2026-01-03 00:00:00', '2026-01-03 06:00:00',
#                ...
#                '2026-01-28 18:00:00', '2026-01-29 00:00:00',
#                '2026-01-29 06:00:00', '2026-01-29 12:00:00',
#                '2026-01-29 18:00:00', '2026-01-30 00:00:00',
#                '2026-01-30 06:00:00', '2026-01-30 12:00:00',
#                '2026-01-30 18:00:00', '2026-01-31 00:00:00'],
#               dtype='datetime64[us]', length=121, freq='6h')

# %%
# M -> Month end
pd.date_range(start='2026/1/1', end='2026/2/28', freq='ME')
# Out:
# DatetimeIndex(['2026-01-31', '2026-02-28'], dtype='datetime64[us]', freq='ME')

# %%
# MS -> Month start
# M -> Month end
pd.date_range(start='2026/1/1', end='2026/2/28', freq='MS')
# Out:
# DatetimeIndex(['2026-01-01', '2026-02-01'], dtype='datetime64[us]', freq='MS')

# %%
# A -> Year end
pd.date_range(start='2026/1/1', end='2030/2/28', freq='YE')
# Out:
# DatetimeIndex(['2026-12-31', '2027-12-31', '2028-12-31', '2029-12-31'], dtype='datetime64[us]', freq='YE-DEC')

# %%
# using periods(number of results)
# M -> Month end
pd.date_range(start='2026/1/1',periods=25, freq='6h')
# Out:
# DatetimeIndex(['2026-01-01 00:00:00', '2026-01-01 06:00:00',
#                '2026-01-01 12:00:00', '2026-01-01 18:00:00',
#                '2026-01-02 00:00:00', '2026-01-02 06:00:00',
#                '2026-01-02 12:00:00', '2026-01-02 18:00:00',
#                '2026-01-03 00:00:00', '2026-01-03 06:00:00',
#                '2026-01-03 12:00:00', '2026-01-03 18:00:00',
#                '2026-01-04 00:00:00', '2026-01-04 06:00:00',
#                '2026-01-04 12:00:00', '2026-01-04 18:00:00',
#                '2026-01-05 00:00:00', '2026-01-05 06:00:00',
#                '2026-01-05 12:00:00', '2026-01-05 18:00:00',
#                '2026-01-06 00:00:00', '2026-01-06 06:00:00',
#                '2026-01-06 12:00:00', '2026-01-06 18:00:00',
#                '2026-01-07 00:00:00'],
#               dtype='datetime64[us]', freq='6h')

# %% [markdown]
# **to_datetime Function**

# %%
# simple series example :

s = pd.Series(['2026-1-1', '2027-1-1', '2028-1-1'])

s = pd.to_datetime(s)
s.dt.year
# Out:
# 0    2026
# 1    2027
# 2    2028
# dtype: int32

# %%
s.dt.month
# Out:
# 0    1
# 1    1
# 2    1
# dtype: int32

# %%
s.dt.day_name()
# Out:
# 0    Thursday
# 1      Friday
# 2    Saturday
# dtype: str

# %%
s.dt.month_name()
# Out:
# 0    January
# 1    January
# 2    January
# dtype: str

# %%
# with errors
s = pd.Series(['2026-1-1', '2027-1-41', '2028-1-1'])
pd.to_datetime(s, errors='coerce')
# Out:
# 0   2026-01-01
# 1          NaT
# 2   2028-01-01
# dtype: datetime64[us]

# %%
df = pd.read_csv('/workspaces/Python-For-Data-Science/Database from Kaggle/expense_data.csv')
df.shape
# Out:
# (277, 11)

# %%
df.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    str
#  1   Account         277 non-null    str
#  2   Category        277 non-null    str
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    str
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    str
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    str
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), str(6)
# memory usage: 23.9 KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[us]
#  1   Account         277 non-null    str
#  2   Category        277 non-null    str
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    str
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    str
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    str
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[us](1), float64(5), str(5)
# memory usage: 23.9 KB

# %% [markdown]
# **dt accessor**

# %%
df['Date'].dt.year
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 272    2021
# 273    2021
# 274    2021
# 275    2021
# 276    2021
# Name: Date, Length: 277, dtype: int32

# %%
df['Date'].dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 272    11
# 273    11
# 274    11
# 275    11
# 276    11
# Name: Date, Length: 277, dtype: int32

# %%
df['Date'].dt.month_name()
# Out:
# 0         March
# 1         March
# 2         March
# 3         March
# 4         March
#          ...
# 272    November
# 273    November
# 274    November
# 275    November
# 276    November
# Name: Date, Length: 277, dtype: str

# %%
df['Date'].dt.is_month_end
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# Name: Date, Length: 277, dtype: bool

# %%
# plot graph 
import matplotlib.pyplot as plt
plt.plot(df['Date'], df['INR'])

# %%
# day name wise bar chart/ month wise bar chart

df['day_n']= df['Date'].dt.day_name()
df.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#        day_n
# 0  Wednesday
# 1  Wednesday
# 2    Tuesday
# ...

# %%
df.groupby('day_n')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='day_n'>

# %%
df['month_n']= df['Date'].dt.month_name()
df.groupby('month_n')["INR"].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='month_n'>

# %%
df[df['Date'].dt.is_month_end].head()
# Out:
#                   Date               Account        Category  Subcategory  \
# 7  2022-02-28 11:56:00  CUB - online payment            Food          NaN
# 8  2022-02-28 11:45:00  CUB - online payment           Other          NaN
# 61 2022-01-31 08:44:00  CUB - online payment  Transportation          NaN
# 62 2022-01-31 08:27:00  CUB - online payment           Other          NaN
# 63 2022-01-31 08:26:00  CUB - online payment  Transportation          NaN
#
#               Note     INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 7            Pizza  339.15        Expense     NaN  339.15      INR     339.15
# 8      From kumara  200.00         Income     NaN  200.00      INR     200.00
# 61      Vnr to apk   50.00        Expense     NaN   50.00      INR      50.00
# 62        To vicky  200.00        Expense     NaN  200.00      INR     200.00
# 63  To ksr station  153.00        Expense     NaN  153.00      INR     153.00
#
#        day_n     day_m   month_n
# ...
