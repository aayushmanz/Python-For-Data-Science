# %% [markdown]
# # Scatter Plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.linspace(-10, 10, 50)
y = 10*x + 3 + np.random.randint(0,300,50)
y
# Out:
# array([-19.        , 167.08163265, 150.16326531,  23.24489796,
#        -80.67346939, 205.40816327, 138.48979592, 118.57142857,
#        209.65306122, 167.73469388,  90.81632653,  27.89795918,
#        -32.02040816, 202.06122449, 242.14285714,  15.2244898 ,
#         50.30612245, 156.3877551 , 224.46938776, -11.44897959,
#        109.63265306, 249.71428571, 133.79591837, 164.87755102,
#        273.95918367, 181.04081633, 143.12244898, 309.20408163,
#         89.28571429, 184.36734694,  56.44897959, 168.53061224,
#        219.6122449 , 303.69387755, 207.7755102 , 329.85714286,
#        175.93877551, 239.02040816, 337.10204082, 194.18367347,
#        243.26530612,  92.34693878, 140.42857143, 306.51020408,
#        142.59183673, 146.67346939, 374.75510204, 148.83673469,
#        307.91836735, 225.        ])

# %%
plt.scatter(x,y)

# %%
df = pd.read_csv('/workspaces/Python-For-Data-Science/Matplotlib in Python/Dataset for matplotlib/batter.csv')

# %%
df = df.head(50)
df
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.style.use('dark_background')
plt.grid()
plt.scatter(df['avg'], df['strike_rate'], color='yellow', marker='+')
plt.title('Avg and SR Analysis of 50 batsman')
plt.xlabel('Avg')
plt.ylabel('Strike rate')
# Out:
# Text(0, 0.5, 'Strike rate')

# %%
# marker

# %%
# size

tips = sns.load_dataset('tips')


plt.scatter(tips['total_bill'], tips['tip'], s=tips['size']*20)
# s= is use for aranging the size of dots according the size of number ( values ) they have

# %%
plt.plot(tips['total_bill'], tips['tip'], 'o')

# this the faster technique
# we can use the plot method for creating the scatter plot.
